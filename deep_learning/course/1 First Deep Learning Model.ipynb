# %% [markdown]
# # First Deep Learning Model

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from sklearn.datasets.samples_generator import make_circles
# Out:
# /Users/vn04q89/.conda/envs/untitled/lib/python3.7/site-packages/sklearn/utils/deprecation.py:143: FutureWarning: The sklearn.datasets.samples_generator module is  deprecated in version 0.22 and will be removed in version 0.24. The corresponding classes / functions should instead be imported from sklearn.datasets. Anything that cannot be imported from sklearn.datasets is now part of the private API.
#   warnings.warn(message, FutureWarning)

# %%
X, y = make_circles(n_samples=1000,
                    noise=0.1,
                    factor=0.2,
                    random_state=0)

# %%
X
# Out:
# array([[ 0.24265541,  0.0383196 ],
#        [ 0.04433036, -0.05667334],
#        [-0.78677748, -0.75718576],
#        ...,
#        [ 0.0161236 , -0.00548034],
#        [ 0.20624715,  0.09769677],
#        [-0.19186631,  0.08916672]])

# %%
X.shape
# Out:
# (1000, 2)

# %%
plt.figure(figsize=(5, 5))
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5, 1.0, 'Blue circles and Red crosses')

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()

# %%
model.add(Dense(4, input_shape=(2,), activation='tanh'))

# %%
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(SGD(lr=0.5), 'binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=20)
# Out:
# Epoch 1/20
# 1000/1000 [==============================] - 0s 119us/step - loss: 0.6514 - accuracy: 0.6800
# Epoch 2/20
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.5257 - accuracy: 0.8530
# Epoch 3/20
# 1000/1000 [==============================] - 0s 25us/step - loss: 0.3618 - accuracy: 0.9980
# Epoch 4/20
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.2391 - accuracy: 1.0000
# Epoch 5/20
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.1692 - accuracy: 1.0000
# Epoch 6/20
# 1000/1000 [==============================] - 0s 26us/step - loss: 0.1273 - accuracy: 1.0000
# Epoch 7/20
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.1011 - accuracy: 1.0000
# Epoch 8/20
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.0835 - accuracy: 1.0000
# Epoch 9/20
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0707 - accuracy: 1.0000
# Epoch 10/20
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0613 - accuracy: 1.0000
# Epoch 11/20
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.0540 - accuracy: 0.9990
# Epoch 12/20
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.0482 - accuracy: 1.0000
# Epoch 13/20
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.0436 - accuracy: 0.9990
# Epoch 14/20
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0398 - accuracy: 1.0000
# Epoch 15/20
# 1000/1000 [==============================] - 0s 30us/step - loss: 0.0366 - accuracy: 1.0000
# Epoch 16/20
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.0340 - accuracy: 0.9990
# Epoch 17/20
# 1000/1000 [==============================] - 0s 28us/step - loss: 0.0316 - accuracy: 0.9990
# Epoch 18/20
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.0295 - accuracy: 0.9990
# Epoch 19/20
# 1000/1000 [==============================] - 0s 27us/step - loss: 0.0278 - accuracy: 0.9990
# Epoch 20/20
# 1000/1000 [==============================] - 0s 29us/step - loss: 0.0263 - accuracy: 0.9990

# %%
hticks = np.linspace(-1.5, 1.5, 101)
vticks = np.linspace(-1.5, 1.5, 101)
aa, bb = np.meshgrid(hticks, vticks)
ab = np.c_[aa.ravel(), bb.ravel()]
c = model.predict(ab)
cc = c.reshape(aa.shape)

# %%
plt.figure(figsize=(5, 5))
plt.contourf(aa, bb, cc, cmap='bwr', alpha=0.2)
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5, 1.0, 'Blue circles and Red crosses')
